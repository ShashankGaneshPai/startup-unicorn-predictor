# %%
import pandas as pd
import joblib
import os

# %%
df = pd.read_csv("processed_startup_data.csv")

df.head()
# Out:
#    founded_year  funding_amount_usd  employee_count  estimated_revenue_usd  \
# 0          2008           20.454141             106              19.484970
# 1          2006           19.755663             735              17.637135
# 2          2010           21.644890             346              18.819120
# 3          2013           20.751934             302              19.895324
# 4          2012           19.397995             286              17.720862
#
#    unicorn  funding_year  funding_month  startup_age  investor_count  \
# 0        1          2020              3           18               1
# 1        1          2017              4           20               3
# 2        1          2015              9           16               1
# 3        1          2018             10           13               2
# 4        1          2020              1           14               1
#
#    country_freq  ...  funding_round_Series A  funding_round_Series B  \
# ...

# %%
print(df.shape)
# Out:
# (50000, 33)

# %%
X = df.drop(
    columns=[
        "unicorn",
        "estimated_revenue_usd"
    ]
)

y = df["unicorn"]

# %%
print(X.columns.tolist())
# Out:
# ['founded_year', 'funding_amount_usd', 'employee_count', 'funding_year', 'funding_month', 'startup_age', 'investor_count', 'country_freq', 'region_Europe', 'region_Latin America', 'region_MENA', 'region_North America', 'region_Oceania', 'industry_Blockchain', 'industry_E-commerce', 'industry_Fintech', 'industry_Healthcare', 'industry_Logistics', 'industry_SaaS', 'funding_round_Pre-Seed', 'funding_round_Seed', 'funding_round_Series A', 'funding_round_Series B', 'funding_round_Series C', 'funding_round_Series D', 'lead_investor_Andreessen Horowitz', 'lead_investor_Index Ventures', 'lead_investor_Sequoia', 'lead_investor_SoftBank', 'lead_investor_Tiger Global', 'lead_investor_Y Combinator']

# %%
feature_columns = X.columns.tolist()

joblib.dump(
    feature_columns,
    "feature_columns.pkl"
)
# Out:
# ['feature_columns.pkl']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
final_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    min_samples_split=5,
    min_samples_leaf=4,
    random_state=42
)

# %%
final_model.fit(
    X_train,
    y_train
)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=200, random_state=42)

# %%
joblib.dump(
    final_model,
    "unicorn_predictor.pkl"
)
# Out:
# ['unicorn_predictor.pkl']

# %%
print(
    os.path.exists(
        "unicorn_predictor.pkl"
    )
)
# Out:
# True

# %%
print(
    os.path.exists(
        "feature_columns.pkl"
    )
)
# Out:
# True

# %%
loaded_model = joblib.load(
    "unicorn_predictor.pkl"
)

loaded_model
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=200, random_state=42)

# %%
loaded_features = joblib.load(
    "feature_columns.pkl"
)

print(
    loaded_features[:10]
)
# Out:
# ['founded_year', 'funding_amount_usd', 'employee_count', 'funding_year', 'funding_month', 'startup_age', 'investor_count', 'country_freq', 'region_Europe', 'region_Latin America']

# %%
sample = X.iloc[[0]]

# %%
prediction = loaded_model.predict(
    sample
)

probability = loaded_model.predict_proba(
    sample
)

# %%
print(
    "Prediction:",
    prediction[0]
)

print(
    "Probability:",
    probability[0][1]
)
# Out:
# Prediction: 1
# Probability: 0.9465040843638038

# %%
import joblib

model = joblib.load("unicorn_predictor.pkl")
features = joblib.load("feature_columns.pkl")

print(type(model))
print(len(features))
print(features[:5])
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# 31
# ['founded_year', 'funding_amount_usd', 'employee_count', 'funding_year', 'funding_month']

# %%
features = joblib.load("feature_columns.pkl")

for i, col in enumerate(features, start=1):
    print(i, col)
# Out:
# 1 founded_year
# 2 funding_amount_usd
# 3 employee_count
# 4 funding_year
# 5 funding_month
# 6 startup_age
# 7 investor_count
# 8 country_freq
# 9 region_Europe
# 10 region_Latin America
# 11 region_MENA
# 12 region_North America
# 13 region_Oceania
# 14 industry_Blockchain
# 15 industry_E-commerce
# 16 industry_Fintech
# 17 industry_Healthcare
# 18 industry_Logistics
# 19 industry_SaaS
# 20 funding_round_Pre-Seed
# 21 funding_round_Seed
# 22 funding_round_Series A
# 23 funding_round_Series B
# 24 funding_round_Series C
# 25 funding_round_Series D
# 26 lead_investor_Andreessen Horowitz
# 27 lead_investor_Index Ventures
# 28 lead_investor_Sequoia
# 29 lead_investor_SoftBank
# 30 lead_investor_Tiger Global
# 31 lead_investor_Y Combinator

# %%
import joblib

country_freq = df["country"].value_counts(
    normalize=True
).to_dict()

joblib.dump(
    country_freq,
    "../models/country_freq.pkl"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 3
#       1 import joblib
# ...
